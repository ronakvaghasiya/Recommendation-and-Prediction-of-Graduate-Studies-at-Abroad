# %%
from tkinter import filedialog
from tkinter import ttk
from tkinter import messagebox

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlplt
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
data = pd.read_csv('lor250.csv', names=['lor','rating'])

# %%
def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
    text = " ".join(text)
    return(text)

# %%
import nltk
nltk.download('stopwords')

# %%
import tkinter as tk
from tkinter import *
import tkinter.font as font
from PIL import Image,ImageTk
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import pickle
model=pickle.load(open('LorRatingmodel','rb'))



data["review_clean"] = data["lor"].apply(lambda x: clean_text(x))

def rate():
    lor=text.get("1.0",END)
    l1 = clean_text(lor)
    l=[l1]
    wordvector = CountVectorizer()
    finalwordvector = wordvector.fit(data['review_clean'])
    l2 = finalwordvector.transform(l)
    tfidf = TfidfTransformer().fit(l2)
    l3 = tfidf.transform(l2)
    lor_rate = str(model.predict(l3[0]))
    message = "Your rate is: ",lor_rate[3]
    messagebox.showinfo("LOR Rating",message)
'''root=Tk()  
#App Title  
root.title("LOR RATING")
style=ttk.Style()
style.configure('btn.TButton',borderwidth = 4,relief='solid')
myFont = font.Font(weight="bold",size=20)

ttk.Label(root, text="COPY YOUR LOR HERE", font=(16),background='#49A').pack()
panedwindow=ttk.Panedwindow(root, orient=HORIZONTAL)  
panedwindow.pack(fill=BOTH, expand=True)
fram1=ttk.Frame(panedwindow,width=500, relief=SUNKEN)  
fram2=ttk.Frame(panedwindow,width=700,height=1000, relief=SUNKEN)  
panedwindow.add(fram1, weight=9)  
panedwindow.add(fram2, weight=6)

root.title('Text')
text = Text(fram1, height=100, width=100)
scroll = Scrollbar(root, command=text.yview)

text.configure(yscrollcommand=scroll.set)

text.tag_configure('bold_italics', 
                   font=('Verdana', 12, 'bold', 'italic'))

text.tag_configure('big', 
                   font=('Verdana', 24, 'bold'))
text.tag_configure('color', 
                   foreground='blue', 
                   font=('Tempus Sans ITC', 14))
                   
text.tag_configure('groove', 
                   relief=GROOVE, 
                   borderwidth=2)
                   
text.tag_bind('bite', 
              '<1>', 
              lambda e, t=text: t.insert(END, "Text"))

button = Button(text, text='GET RATING', command=rate,fg='purple', bg='turquoise', font=('comicsans', 14))
text.window_create(END, window=button)
text.pack(side=LEFT)
scroll.pack(side=RIGHT, fill=Y)

im = Image.open("lor.png")
resized = im.resize((700, 700),Image.ANTIALIAS)
tkimage = ImageTk.PhotoImage(resized)
myvar=Label(fram2,image = tkimage)
myvar.image = tkimage
myvar.grid(row=0,column=0,padx=(5,5),pady=(5,5)) 
text1 = Text(fram2)
text1.insert(END, 'Copy the highlighted portion of your lor as shown in above figure and paste it in the textarea\n')
text1.grid(row=1,column=0,padx=(6,6),pady=(5,5))
#button1 = ttk.Button(fram1,text="Get Rating",command=rate).pack(side=LEFT)

root.mainloop()'''
top = Tk()

#top.geometry("900x700")

top.title("RS")

top.columnconfigure(0, pad=3)
top.columnconfigure(1, pad=3)
top.columnconfigure(2, pad=3)
top.columnconfigure(3, pad=3)

top.rowconfigure(0, pad=3)
top.rowconfigure(1, pad=3)
top.rowconfigure(2, pad=3)
top.rowconfigure(3, pad=3)
top.rowconfigure(4, pad=3)

lbl = Label(top, text = " COPY your LOR here")
lbl.grid(row=0,column=0, columnspan=4)
text = Text(top)#height=20, width=50)
text.grid(row=1, rowspan=3,columnspan=2, padx=(5,5),pady=(5,5))
im = Image.open("lor.png")
#resized = im.resize((500, 500),Image.ANTIALIAS)
tkimage = ImageTk.PhotoImage(im)
myvar=Label(top,image = tkimage)
myvar.image = tkimage
myvar.grid(row=1,column=2,rowspan=3,columnspan=2,padx=(5,5),pady=(5,5))
sub = Button(top, text="Get LOR",command=rate)
sub.grid(row=4, columnspan=2)
lbl1 = Label(top, text = " Copy the highlighted portion of your lor as shown in above figure and paste it in the textarea")
lbl1.grid(row=4,column=2,columnspan=2,padx=(5,5),pady=(5,5))

top.mainloop()
